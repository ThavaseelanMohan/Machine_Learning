# %%
# !python --version
# Out:
# Python 3.12.4

# %%
import pandas as pd
import numpy as np#
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"/Users/thavaseelan/Downloads/MLDM Assignment Dataset/Mental health Depression disorder Data.xlsx")

# %%
df
# Out:
#            Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0     Afghanistan  AFG  1990           0.160560              0.697779
# 1     Afghanistan  AFG  1991           0.160312              0.697961
# 2     Afghanistan  AFG  1992           0.160135              0.698107
# 3     Afghanistan  AFG  1993           0.160037              0.698257
# 4     Afghanistan  AFG  1994           0.160022              0.698469
# ...           ...  ...   ...                ...                   ...
# 6463     Zimbabwe  ZWE  2013           0.155670              0.607993
# 6464     Zimbabwe  ZWE  2014           0.155993              0.608610
# 6465     Zimbabwe  ZWE  2015           0.156465              0.609363
# 6466     Zimbabwe  ZWE  2016           0.157111              0.610234
# 6467     Zimbabwe  ZWE  2017           0.157963              0.611242
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# ...

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Schizophrenia (%)', 'Bipolar disorder (%)',
#        'Eating disorders (%)', 'Anxiety disorders (%)',
#        'Drug use disorders (%)', 'Depression (%)',
#        'Alcohol use disorders (%)'],
#       dtype='object')

# %%
df['Entity'].value_counts()
# Out:
# Entity
# Afghanistan                     28
# Niger                           28
# North Africa and Middle East    28
# North America                   28
# North Korea                     28
#                                 ..
# Grenada                         28
# Guam                            28
# Guatemala                       28
# Guinea                          28
# Zimbabwe                        28
# Name: count, Length: 231, dtype: int64

# %%
df['Year'].min()
# Out:
# 1990

# %%
df['Year'].max()
# Out:
# 2017

# %%
df.isna().sum()
# Out:
# Entity                         0
# Code                         980
# Year                           0
# Schizophrenia (%)              0
# Bipolar disorder (%)           0
# Eating disorders (%)           0
# Anxiety disorders (%)          0
# Drug use disorders (%)         0
# Depression (%)                 0
# Alcohol use disorders (%)      0
# dtype: int64

# %%
df = df.rename(columns={"Schizophrenia (%)":"Schizophrenia","Bipolar disorder (%)":"Bipolar","Eating disorders (%)":"Eating","Anxiety disorders (%)":"Anxiety","Drug use disorders (%)":"Drug use","Depression (%)":"Depression","Alcohol use disorders (%)":"Alcohol use"})

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
scal = MinMaxScaler()

# %%
df[["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"]] = scal.fit_transform(df[["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"]])

# %%
df
# Out:
#            Entity Code  Year  Schizophrenia   Bipolar    Eating   Anxiety  \
# 0     Afghanistan  AFG  1990       0.059848  0.429617  0.032120  0.404012
# 1     Afghanistan  AFG  1991       0.058763  0.429820  0.029199  0.404144
# 2     Afghanistan  AFG  1992       0.057987  0.429984  0.026186  0.404341
# 3     Afghanistan  AFG  1993       0.057560  0.430152  0.023478  0.404305
# 4     Afghanistan  AFG  1994       0.057494  0.430390  0.021299  0.404098
# ...           ...  ...   ...            ...       ...       ...       ...
# 6463     Zimbabwe  ZWE  2013       0.038421  0.328966  0.049812  0.153627
# 6464     Zimbabwe  ZWE  2014       0.039836  0.329658  0.050760  0.154173
# 6465     Zimbabwe  ZWE  2015       0.041906  0.330502  0.052366  0.154854
# 6466     Zimbabwe  ZWE  2016       0.044736  0.331479  0.054648  0.155661
# 6467     Zimbabwe  ZWE  2017       0.048471  0.332609  0.058082  0.156616
#
#       Drug use  Depression  Alcohol use
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Entity         6468 non-null   object
#  1   Code           5488 non-null   object
#  2   Year           6468 non-null   int64
#  3   Schizophrenia  6468 non-null   float64
#  4   Bipolar        6468 non-null   float64
#  5   Eating         6468 non-null   float64
#  6   Anxiety        6468 non-null   float64
#  7   Drug use       6468 non-null   float64
#  8   Depression     6468 non-null   float64
#  9   Alcohol use    6468 non-null   float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 505.4+ KB

# %%
df.describe()
# Out:
#               Year  Schizophrenia      Bipolar       Eating      Anxiety  \
# count  6468.000000    6468.000000  6468.000000  6468.000000  6468.000000
# mean   2003.500000       0.283697     0.453568     0.190891     0.283201
# std       8.078372       0.193915     0.192350     0.181754     0.168136
# min    1990.000000       0.000000     0.000000     0.000000     0.000000
# 25%    1996.750000       0.151738     0.337418     0.055718     0.167834
# 50%    2003.500000       0.230760     0.424410     0.124835     0.220477
# 75%    2010.250000       0.392026     0.583511     0.251423     0.382891
# max    2017.000000       1.000000     1.000000     1.000000     1.000000
#
#           Drug use   Depression  Alcohol use
# count  6468.000000  6468.000000  6468.000000
# mean      0.155964     0.304234     0.226520
# std       0.150116     0.146960     0.171108
# min       0.000000     0.000000     0.000000
# 25%       0.049339     0.193963     0.108746
# ...

# %%
df = df.drop("Code", axis=1)

# %%
df
# Out:
#            Entity  Year  Schizophrenia   Bipolar    Eating   Anxiety  \
# 0     Afghanistan  1990       0.059848  0.429617  0.032120  0.404012
# 1     Afghanistan  1991       0.058763  0.429820  0.029199  0.404144
# 2     Afghanistan  1992       0.057987  0.429984  0.026186  0.404341
# 3     Afghanistan  1993       0.057560  0.430152  0.023478  0.404305
# 4     Afghanistan  1994       0.057494  0.430390  0.021299  0.404098
# ...           ...   ...            ...       ...       ...       ...
# 6463     Zimbabwe  2013       0.038421  0.328966  0.049812  0.153627
# 6464     Zimbabwe  2014       0.039836  0.329658  0.050760  0.154173
# 6465     Zimbabwe  2015       0.041906  0.330502  0.052366  0.154854
# 6466     Zimbabwe  2016       0.044736  0.331479  0.054648  0.155661
# 6467     Zimbabwe  2017       0.048471  0.332609  0.058082  0.156616
#
#       Drug use  Depression  Alcohol use
# 0     0.421474    0.432891     0.044844
# 1     0.423972    0.434616     0.044718
# ...

# %%
## Remove Outliers
for i in ['Schizophrenia','Bipolar','Eating','Anxiety','Drug use','Depression','Alcohol use']:
    Q1 = df[i].quantile(0.05)
    Q2 = df[i].quantile(0.90)
    IQR = Q2 - Q1
    lower = Q1 - 3 * IQR
    upper = Q2 +3 * IQR
    df = df[(df[i] >= lower) & (df[i] <= upper)]
df
# Out:
#            Entity  Year  Schizophrenia   Bipolar    Eating   Anxiety  \
# 0     Afghanistan  1990       0.059848  0.429617  0.032120  0.404012
# 1     Afghanistan  1991       0.058763  0.429820  0.029199  0.404144
# 2     Afghanistan  1992       0.057987  0.429984  0.026186  0.404341
# 3     Afghanistan  1993       0.057560  0.430152  0.023478  0.404305
# 4     Afghanistan  1994       0.057494  0.430390  0.021299  0.404098
# ...           ...   ...            ...       ...       ...       ...
# 6463     Zimbabwe  2013       0.038421  0.328966  0.049812  0.153627
# 6464     Zimbabwe  2014       0.039836  0.329658  0.050760  0.154173
# 6465     Zimbabwe  2015       0.041906  0.330502  0.052366  0.154854
# 6466     Zimbabwe  2016       0.044736  0.331479  0.054648  0.155661
# 6467     Zimbabwe  2017       0.048471  0.332609  0.058082  0.156616
#
#       Drug use  Depression  Alcohol use
# 0     0.421474    0.432891     0.044844
# 1     0.423972    0.434616     0.044718
# ...

# %%
Normalize = df.groupby('Entity').agg({
    'Schizophrenia':'mean',
    'Bipolar':'mean',
    'Eating':'mean',
    'Anxiety':'mean',
    'Drug use':'mean',
    'Depression':'mean',
    'Alcohol use':'mean'
}).reset_index()

# %%
Normalize
# Out:
#                          Entity  Schizophrenia   Bipolar    Eating   Anxiety  \
# 0                   Afghanistan       0.070427  0.434745  0.023393  0.406788
# 1                       Albania       0.217529  0.432209  0.081972  0.193768
# 2                       Algeria       0.210590  0.555308  0.138585  0.430304
# 3                American Samoa       0.450833  0.171020  0.123381  0.182882
# 4          Andean Latin America       0.221393  0.629502  0.278566  0.319984
# ..                          ...            ...       ...       ...       ...
# 226  Western Sub-Saharan Africa       0.106574  0.357568  0.057802  0.123131
# 227                       World       0.469508  0.308834  0.133488  0.254712
# 228                       Yemen       0.108719  0.469438  0.064120  0.404617
# 229                      Zambia       0.061409  0.322676  0.057066  0.221429
# 230                    Zimbabwe       0.056304  0.328327  0.065620  0.153857
#
#      Drug use  Depression  Alcohol use
# ...

# %%
import plotly.express as px

# %%
df_Schizophrenia = Normalize.sort_values(by="Schizophrenia", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Schizophrenia.head(), x='Entity', y='Schizophrenia',
             title='Countries having highest number of patients with Schizophrenia disorder',
             labels={'Entity': 'Country', 'Schizophrenia': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="59b1895a-8029-4e3f-9a69-d79e6c03c572" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59b1895a-8029-4e3f-9a69-d79e6c03c572")) {                    Plotly.newPlot(                        "59b1895a-8029-4e3f-9a69-d79e6c03c572",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Netherlands","Australia","Australasia","New Zealand","United States"],"xaxis":"x","y":[0.9878189737013893,0.9534993760586037,0.9361562462017821,0.8466473832888349,0.8378985824325051],"yaxis":"y","typ
# ...

# %%
df_Schizophrenia = Normalize.sort_values(by="Schizophrenia", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Schizophrenia.tail(), x='Entity', y='Schizophrenia',
             title='Countries having least number of patients with Schizophrenia disorder',
             labels={'Entity': 'Country', 'Schizophrenia': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="a5d780c1-3a0b-4264-a505-f3fa12c833f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5d780c1-3a0b-4264-a505-f3fa12c833f9")) {                    Plotly.newPlot(                        "a5d780c1-3a0b-4264-a505-f3fa12c833f9",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Burundi","Somalia","Malawi","Mozambique","Central African Republic"],"xaxis":"x","y":[0.029364498809415225,0.02850380464851973,0.02383119841483548,0.017624945658796718,0.008698574740455147],"yaxis":"
# ...

# %%
df_Bipolar = Normalize.sort_values(by="Bipolar", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Bipolar.head(), x='Entity', y='Bipolar',
             title='Countries having highest number of patients with Bipolar disorder',
             labels={'Entity': 'Country', 'Bipolar': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="11a2c806-0c9d-4708-943b-31f26f60c1de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11a2c806-0c9d-4708-943b-31f26f60c1de")) {                    Plotly.newPlot(                        "11a2c806-0c9d-4708-943b-31f26f60c1de",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["New Zealand","Australasia","Australia","Northern Ireland","England"],"xaxis":"x","y":[0.9914991711083071,0.9403944874489948,0.9305688852236542,0.9286247851664567,0.8870534307737775],"yaxis":"y","type
# ...

# %%
df_Bipolar = Normalize.sort_values(by="Bipolar", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Bipolar.tail(), x='Entity', y='Bipolar',
             title='Countries having least number of patients with Bipolar disorder',
             labels={'Entity': 'Country', 'Bipolar': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="8d19ce85-d035-41c5-a600-5ac036a4e1be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d19ce85-d035-41c5-a600-5ac036a4e1be")) {                    Plotly.newPlot(                        "8d19ce85-d035-41c5-a600-5ac036a4e1be",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Southeast Asia, East Asia, and Oceania","Taiwan","North Korea","East Asia","China"],"xaxis":"x","y":[0.07284373701692351,0.04018022670555948,0.01206147418863257,0.006566194250296457,0.005935566035135
# ...

# %%
df_Eating = Normalize.sort_values(by="Eating", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Eating.head(), x='Entity', y='Eating',
             title='Countries having highest number of patients with Eating disorder',
             labels={'Entity': 'Country', 'Eating': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="7e8b30e5-68c9-4f58-ae9a-e258ed30222c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e8b30e5-68c9-4f58-ae9a-e258ed30222c")) {                    Plotly.newPlot(                        "7e8b30e5-68c9-4f58-ae9a-e258ed30222c",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Australia","Australasia","Luxembourg","Spain","New Zealand"],"xaxis":"x","y":[0.8784940054902173,0.8421526570593755,0.7036817627202939,0.6789349069961458,0.6543363716906365],"yaxis":"y","type":"bar"}
# ...

# %%
df_Eating = Normalize.sort_values(by="Eating", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Eating.tail(), x='Entity', y='Eating',
             title='Countries having least number of patients with Eating disorder',
             labels={'Entity': 'Country', 'Eating': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="a977e0e6-ef96-4d65-8233-0ff4bdc7aeee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a977e0e6-ef96-4d65-8233-0ff4bdc7aeee")) {                    Plotly.newPlot(                        "a977e0e6-ef96-4d65-8233-0ff4bdc7aeee",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Democratic Republic of Congo","Mozambique","Ethiopia","Liberia","Somalia"],"xaxis":"x","y":[0.016335972257869587,0.015012133465737059,0.014249953732498254,0.012351922006672164,0.005033648193095499],"
# ...

# %%
df_Anxiety = Normalize.sort_values(by="Anxiety", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Anxiety.head(), x='Entity', y='Anxiety',
             title='Countries having highest number of patients with Anxiety disorder',
             labels={'Entity': 'Country', 'Anxiety': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="5cab545b-61a4-4839-b912-bbc233bfb48c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cab545b-61a4-4839-b912-bbc233bfb48c")) {                    Plotly.newPlot(                        "5cab545b-61a4-4839-b912-bbc233bfb48c",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["New Zealand","Northern Ireland","Norway","Iran","Australasia"],"xaxis":"x","y":[0.9544896093266261,0.8357698761836642,0.8084707994365533,0.7069697398112075,0.7016850036555661],"yaxis":"y","type":"bar
# ...

# %%
df_Anxiety = Normalize.sort_values(by="Anxiety", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Anxiety.tail(), x='Entity', y='Anxiety',
             title='Countries having least number of patients with Anxiety disorder',
             labels={'Entity': 'Country', 'Anxiety': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="6c0580ae-59eb-4c91-ad33-2db50c172480" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c0580ae-59eb-4c91-ad33-2db50c172480")) {                    Plotly.newPlot(                        "6c0580ae-59eb-4c91-ad33-2db50c172480",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Kyrgyzstan","Uzbekistan","Mongolia","Tajikistan","Vietnam"],"xaxis":"x","y":[0.0763348763197114,0.07467473813309036,0.07239507255095755,0.07049319490384644,0.0017095739467877374],"yaxis":"y","type":"
# ...

# %%
df_Drug_use = Normalize.sort_values(by="Drug use", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Drug_use.head(), x='Entity', y='Drug use',
             title='Countries having highest number of patients with Drug use disorder',
             labels={'Entity': 'Country', 'Drug use': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="f8671464-7c90-46c5-971f-ac5ab789fab0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8671464-7c90-46c5-971f-ac5ab789fab0")) {                    Plotly.newPlot(                        "f8671464-7c90-46c5-971f-ac5ab789fab0",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["United States","North America","United Arab Emirates","Libya","Australia"],"xaxis":"x","y":[0.8019560429312252,0.7799097020487755,0.7323570160332498,0.5911487255484669,0.5899852140808584],"yaxis":"y"
# ...

# %%
df_Drug_use = Normalize.sort_values(by="Drug use", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Drug_use.tail(), x='Entity', y='Drug use',
             title='Countries having least number of patients with Drug use disorder',
             labels={'Entity': 'Country', 'Drug use': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="b735fed6-8dbe-487f-ac90-8ae85c01b120" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b735fed6-8dbe-487f-ac90-8ae85c01b120")) {                    Plotly.newPlot(                        "b735fed6-8dbe-487f-ac90-8ae85c01b120",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Chad","Guinea","Mali","Burkina Faso","Bosnia and Herzegovina"],"xaxis":"x","y":[0.017446996646298778,0.015083534325868278,0.014023574556885065,0.010658942501356072,0.009509522989866301],"yaxis":"y","
# ...

# %%
df_Depression = Normalize.sort_values(by="Depression", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Depression.head(), x='Entity', y='Depression',
             title='Countries having highest number of patients with Depression',
             labels={'Entity': 'Country', 'Depression': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="5f324a46-b94e-4c59-970c-25dc9a90c12e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f324a46-b94e-4c59-970c-25dc9a90c12e")) {                    Plotly.newPlot(                        "5f324a46-b94e-4c59-970c-25dc9a90c12e",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Greenland","Morocco","Lesotho","Uganda","Finland"],"xaxis":"x","y":[0.9678132231528964,0.7776183888810358,0.7358318978300831,0.6919150764874977,0.6818908814131228],"yaxis":"y","type":"bar"}],        
# ...

# %%
df_Depression = Normalize.sort_values(by="Depression", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Depression.tail(), x='Entity', y='Depression',
             title='Countries having least number of patients with Depression',
             labels={'Entity': 'Country', 'Depression': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="c6883d9a-db6b-4df6-862c-b7cbda51498f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6883d9a-db6b-4df6-862c-b7cbda51498f")) {                    Plotly.newPlot(                        "c6883d9a-db6b-4df6-862c-b7cbda51498f",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Peru","Colombia","Poland","Myanmar","Albania"],"xaxis":"x","y":[0.03979455738530098,0.03838151600526486,0.03237212380340435,0.025143128462693346,0.011324417514493007],"yaxis":"y","type":"bar"}],     
# ...

# %%
df_Alcohol_use = Normalize.sort_values(by="Alcohol use", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Alcohol_use.head(), x='Entity', y='Alcohol use',
             title='Countries having highest number of patients with Alcohol use',
             labels={'Entity': 'Country', 'Alcohol use': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="d2f9de9a-43a6-4247-8c68-e362585c657a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2f9de9a-43a6-4247-8c68-e362585c657a")) {                    Plotly.newPlot(                        "d2f9de9a-43a6-4247-8c68-e362585c657a",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Belarus","Russia","Eastern Europe","Ukraine","Estonia"],"xaxis":"x","y":[0.9625268504219732,0.9371133918809563,0.9266797028362994,0.9174693158353312,0.8891711762510282],"yaxis":"y","type":"bar"}],   
# ...

# %%
df_Alcohol_use = Normalize.sort_values(by="Alcohol use", ascending=False)
plt.figure(figsize=(10,7))
fig = px.bar(df_Alcohol_use.tail(), x='Entity', y='Alcohol use',
             title='Countries having least number of patients with Alcohol use',
             labels={'Entity': 'Country', 'Alcohol use': 'Average share of population'})
fig.show()
# Out:
# <div>                            <div id="7515e589-42be-4ddb-a7f3-7f3cea4e5ce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7515e589-42be-4ddb-a7f3-7f3cea4e5ce0")) {                    Plotly.newPlot(                        "7515e589-42be-4ddb-a7f3-7f3cea4e5ce0",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Average share of population=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Japan","Morocco","Israel","Singapore","Italy"],"xaxis":"x","y":[0.02358963140138163,0.023177160621831727,0.017187636069104364,0.006541666728251538,0.001829611434682903],"yaxis":"y","type":"bar"}],   
# ...

# %%
## Country wise analysis

# %%
df_uk = Normalize[Normalize["Entity"] == "United Kingdom"]

# %%
df_uk_melt = df_uk.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_uk_melt
# Out:
#            Entity       Disorder  Prevalence
# 0  United Kingdom  Schizophrenia    0.462945
# 1  United Kingdom        Bipolar    0.865897
# 2  United Kingdom         Eating    0.498321
# 3  United Kingdom        Anxiety    0.375816
# 4  United Kingdom       Drug use    0.419502
# 5  United Kingdom     Depression    0.455455
# 6  United Kingdom    Alcohol use    0.249534

# %%
plt.figure(figsize=(10,7))

fig = px.pie(df_uk_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in United Kingdom',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="bf54d487-c7b7-4301-8206-54ccb2b18fb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf54d487-c7b7-4301-8206-54ccb2b18fb9")) {                    Plotly.newPlot(                        "bf54d487-c7b7-4301-8206-54ccb2b18fb9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.4629448053275307,0.8658969675506026,0.49832056560896937,0.3758164240705701,0.4195017995195484,0.4554551661606,0.24953364774675008],"type":"pie","textinfo":"percent+label"}],         
# ...

# %%
df_usa = Normalize[Normalize["Entity"] == "United States"]

# %%
df_usa_melt = df_usa.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_usa_melt
# Out:
#           Entity       Disorder  Prevalence
# 0  United States  Schizophrenia    0.837899
# 1  United States        Bipolar    0.380215
# 2  United States         Eating    0.505412
# 3  United States        Anxiety    0.679469
# 4  United States       Drug use    0.801956
# 5  United States     Depression    0.583652
# 6  United States    Alcohol use    0.318176

# %%
plt.figure(figsize=(10,7))

fig = px.pie(df_usa_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in United States',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="9bd2f449-e405-40cf-8841-b6ddcd4ff993" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9bd2f449-e405-40cf-8841-b6ddcd4ff993")) {                    Plotly.newPlot(                        "9bd2f449-e405-40cf-8841-b6ddcd4ff993",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.8378985824325051,0.38021500151424975,0.5054119628029918,0.6794691192802367,0.8019560429312252,0.5836520521913535,0.3181761627894538],"type":"pie","textinfo":"percent+label"}],       
# ...

# %%
df_India = Normalize[Normalize["Entity"] == "India"]

# %%
df_India_melt = df_India.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_India_melt
# Out:
#   Entity       Disorder  Prevalence
# 0  India  Schizophrenia    0.504133
# 1  India        Bipolar    0.268277
# 2  India         Eating    0.058517
# 3  India        Anxiety    0.183829
# 4  India       Drug use    0.037268
# 5  India     Depression    0.366668
# 6  India    Alcohol use    0.180543

# %%
plt.figure(figsize=(10,7))

fig = px.pie(df_India_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in India',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="b395df99-7651-4c2f-88d5-d5c43d679643" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b395df99-7651-4c2f-88d5-d5c43d679643")) {                    Plotly.newPlot(                        "b395df99-7651-4c2f-88d5-d5c43d679643",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.5041333897852094,0.268276804095944,0.05851682351790393,0.18382919741414142,0.03726760450349388,0.36666757491066443,0.1805426169321955],"type":"pie","textinfo":"percent+label"}],     
# ...

# %%
df_Uganda = Normalize[Normalize["Entity"] == "Uganda"]

# %%
df_Uganda_melt = df_Uganda.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_Uganda_melt
# Out:
#    Entity       Disorder  Prevalence
# 0  Uganda  Schizophrenia    0.038584
# 1  Uganda        Bipolar    0.326182
# 2  Uganda         Eating    0.034113
# 3  Uganda        Anxiety    0.208327
# 4  Uganda       Drug use    0.048701
# 5  Uganda     Depression    0.691915
# 6  Uganda    Alcohol use    0.167762

# %%
plt.figure(figsize=(10,7))
fig = px.pie(df_Uganda_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in Uganda',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="e7184868-52be-4012-9545-3bd816821b6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7184868-52be-4012-9545-3bd816821b6b")) {                    Plotly.newPlot(                        "e7184868-52be-4012-9545-3bd816821b6b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.03858364828847143,0.32618181284092723,0.034113273379228475,0.20832744490249952,0.04870076218836856,0.6919150764874977,0.16776183925179225],"type":"pie","textinfo":"percent+label"}], 
# ...

# %%
df_Nigeria = Normalize[Normalize["Entity"] == "Nigeria"]

# %%
df_Nigeria_melt = df_Nigeria.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_Nigeria_melt
# Out:
#     Entity       Disorder  Prevalence
# 0  Nigeria  Schizophrenia    0.127597
# 1  Nigeria        Bipolar    0.363542
# 2  Nigeria         Eating    0.069582
# 3  Nigeria        Anxiety    0.121621
# 4  Nigeria       Drug use    0.020485
# 5  Nigeria     Depression    0.427344
# 6  Nigeria    Alcohol use    0.096087

# %%
plt.figure(figsize=(10,7))

fig = px.pie(df_Nigeria_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in Nigeria',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="2e778a98-0fbb-4af0-adc9-8942dbc50f5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e778a98-0fbb-4af0-adc9-8942dbc50f5e")) {                    Plotly.newPlot(                        "2e778a98-0fbb-4af0-adc9-8942dbc50f5e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.12759681727868327,0.36354230946355953,0.069581770551194,0.12162130052847629,0.020484595329540032,0.42734377939351964,0.09608722647040464],"type":"pie","textinfo":"percent+label"}],  
# ...

# %%
df_Africa = Normalize[Normalize["Entity"] == "South Africa"]

# %%
df_Africa_melt = df_Africa.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_Africa_melt
# Out:
#          Entity       Disorder  Prevalence
# 0  South Africa  Schizophrenia    0.140072
# 1  South Africa        Bipolar    0.355083
# 2  South Africa         Eating    0.147667
# 3  South Africa        Anxiety    0.286432
# 4  South Africa       Drug use    0.244971
# 5  South Africa     Depression    0.354717
# 6  South Africa    Alcohol use    0.237697

# %%
plt.figure(figsize=(10,7))

fig = px.pie(df_Africa_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in South Africa',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="ed3e8c0f-d5da-40a9-8e0e-96c8ab36003d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed3e8c0f-d5da-40a9-8e0e-96c8ab36003d")) {                    Plotly.newPlot(                        "ed3e8c0f-d5da-40a9-8e0e-96c8ab36003d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.14007243438986147,0.35508301787516255,0.14766726514943468,0.286431749786442,0.24497093615280588,0.3547174831172352,0.23769696753907582],"type":"pie","textinfo":"percent+label"}],    
# ...

# %%
df_Somalia = Normalize[Normalize["Entity"] == "Somalia"]

# %%
df_Somalia_melt = df_Somalia.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_Somalia_melt
# Out:
#     Entity       Disorder  Prevalence
# 0  Somalia  Schizophrenia    0.028504
# 1  Somalia        Bipolar    0.338105
# 2  Somalia         Eating    0.005034
# 3  Somalia        Anxiety    0.216112
# 4  Somalia       Drug use    0.033736
# 5  Somalia     Depression    0.365915
# 6  Somalia    Alcohol use    0.217121

# %%
plt.figure(figsize=(10,7))

fig = px.pie(df_Somalia_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in Somalia',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="e5df1b47-93ca-4881-ae6e-d4386093dd99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5df1b47-93ca-4881-ae6e-d4386093dd99")) {                    Plotly.newPlot(                        "e5df1b47-93ca-4881-ae6e-d4386093dd99",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.02850380464851973,0.33810517751561603,0.005033648193095499,0.21611219309529694,0.03373643749532602,0.36591540190178673,0.21712100207949234],"type":"pie","textinfo":"percent+label"}],
# ...

# %%
df_Iran = Normalize[Normalize["Entity"] == "Iran"]

# %%
df_Iran_melt = df_Iran.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_Iran_melt
# Out:
#   Entity       Disorder  Prevalence
# 0   Iran  Schizophrenia    0.226296
# 1   Iran        Bipolar    0.557521
# 2   Iran         Eating    0.152148
# 3   Iran        Anxiety    0.706970
# 4   Iran       Drug use    0.498225
# 5   Iran     Depression    0.612709
# 6   Iran    Alcohol use    0.041655

# %%
plt.figure(figsize=(10,7))

fig = px.pie(df_Iran_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in Iran',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="99ad6db2-b18b-4661-a972-be488350cc60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99ad6db2-b18b-4661-a972-be488350cc60")) {                    Plotly.newPlot(                        "99ad6db2-b18b-4661-a972-be488350cc60",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.2262963689641221,0.5575214002577615,0.15214777302440577,0.7069697398112075,0.4982250255644442,0.6127091917737698,0.041655387829879216],"type":"pie","textinfo":"percent+label"}],     
# ...

# %%
df_Russia = Normalize[Normalize["Entity"] == "Russia"]

# %%
df_Russia_melt = df_Russia.melt(id_vars=["Entity"], var_name="Disorder", value_name="Prevalence")
df_Russia_melt
# Out:
#    Entity       Disorder  Prevalence
# 0  Russia  Schizophrenia    0.197306
# 1  Russia        Bipolar    0.400798
# 2  Russia         Eating    0.154916
# 3  Russia        Anxiety    0.132242
# 4  Russia       Drug use    0.193963
# 5  Russia     Depression    0.369997
# 6  Russia    Alcohol use    0.937113

# %%
plt.figure(figsize=(10,7))

fig = px.pie(df_Russia_melt, values='Prevalence', names='Disorder', hole=0.5,
             title='Mental Health Disorders in Russia',
             labels={'Prevalence': 'Prevalence (%)', 'Disorder': 'Disorder Type'})

fig.update_layout(legend_title_text='Disorder Type')
fig.update_traces(textinfo='percent+label')  # Display percentages and labels inside the donut chart

fig.show()
# Out:
# <div>                            <div id="18126e9d-9e1f-45c1-98ea-27fb0768de92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18126e9d-9e1f-45c1-98ea-27fb0768de92")) {                    Plotly.newPlot(                        "18126e9d-9e1f-45c1-98ea-27fb0768de92",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Disorder Type=%{label}<br>Prevalence (%)=%{value}<extra></extra>","labels":["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"],"legendgroup":"","name":"","showlegend":true,"values":[0.1973056735339759,0.4007975313363571,0.15491560018997735,0.13224220751344257,0.19396320692148397,0.36999721832774907,0.9371133918809563],"type":"pie","textinfo":"percent+label"}],    
# ...

# %%
df_countries_comparison = Normalize[(Normalize["Entity"] == "United States") | (Normalize["Entity"] == "India") | (Normalize["Entity"] == "United Kingdom") | (Normalize["Entity"] == "Nigeria")]
df_countries_comparison.reset_index(drop=True)
# Out:
#            Entity  Schizophrenia   Bipolar    Eating   Anxiety  Drug use  \
# 0           India       0.504133  0.268277  0.058517  0.183829  0.037268
# 1         Nigeria       0.127597  0.363542  0.069582  0.121621  0.020485
# 2  United Kingdom       0.462945  0.865897  0.498321  0.375816  0.419502
# 3   United States       0.837899  0.380215  0.505412  0.679469  0.801956
#
#    Depression  Alcohol use
# 0    0.366668     0.180543
# 1    0.427344     0.096087
# 2    0.455455     0.249534
# 3    0.583652     0.318176

# %%
##Correlation

# %%
df_disorders = Normalize[["Schizophrenia","Bipolar","Eating","Anxiety","Drug use","Depression","Alcohol use"]]

# Plotting the heatmap to find correlation between mental health disorders
plt.figure(figsize=(10,7))
sns.heatmap(df_disorders.corr(), annot=True)
plt.title("Correlation Heatmap for mental health disorders")
plt.show()

# %%
# Using all the five mental health disorders as the features for clustering algorithms
X =  Normalize.iloc[:,1:8]
X.head()
# Out:
#    Schizophrenia   Bipolar    Eating   Anxiety  Drug use  Depression  \
# 0       0.070427  0.434745  0.023393  0.406788  0.566063    0.443376
# 1       0.217529  0.432209  0.081972  0.193768  0.037511    0.011324
# 2       0.210590  0.555308  0.138585  0.430304  0.377014    0.340105
# 3       0.450833  0.171020  0.123381  0.182882  0.122426    0.179470
# 4       0.221393  0.629502  0.278566  0.319984  0.085856    0.109094
#
#    Alcohol use
# 0     0.043004
# 1     0.258530
# 2     0.041126
# 3     0.136906
# 4     0.238564

# %%
sns.pairplot(X)
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning:
#
# The figure layout has changed to tight

# %%
scaler = StandardScaler()
X_Scaled = scaler.fit_transform(X)

# %%
X_Scaled
# Out:
# array([[-1.10213473, -0.09789391, -0.92922853, ...,  2.76579034,
#          0.95587425, -1.07883798],
#        [-0.34194091, -0.11108395, -0.60425021, ..., -0.79887506,
#         -2.01222834,  0.18817526],
#        [-0.37780012,  0.52912516, -0.29017737, ...,  1.49080416,
#          0.24642952, -1.0898749 ],
#        ...,
#        [-0.90424623,  0.08253786, -0.70328628, ...,  0.83821471,
#          0.78089117, -1.11543853],
#        [-1.14873432, -0.68073589, -0.7424197 , ..., -0.77303707,
#          0.08664406,  0.06261014],
#        [-1.17511795, -0.65134942, -0.6949657 , ..., -0.24946092,
#         -0.60743951, -0.11431827]])

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_Scaled)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# ...

# %%
from yellowbrick.cluster import KElbowVisualizer

elbow = KElbowVisualizer(kmeans, k=(2,10))
elbow.fit(X_Scaled)
elbow.show()
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# ...

# %%
# Fitting K-Means to the Dataset

# %%
kmeans = KMeans(n_clusters = 3, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X_Scaled)
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
## Dimensonality Reduction

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
X_reduced = pca.fit_transform(X_Scaled)

pca.explained_variance_ratio_
# Out:
# array([0.47795598, 0.15505389])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.63300986970845

# %%
colours = ['red', 'blue', 'green']

plt.figure(figsize=(8,8))
for i in range(3):
    plt.scatter(X_reduced[y_kmeans == i,0], X_reduced[y_kmeans == i,1], s=100, c=colours[i], label='cluster' +str(i+1))
    plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:, 1], s=100, marker='*', c='orange', label='Centroids'+str(i+1))

plt.title('Cluster of Disorders')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend()
plt.show()

# %%
kmeans = KMeans(n_clusters = 5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X_Scaled)
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
X_reduced = pca.fit_transform(X_Scaled)

pca.explained_variance_ratio_
# Out:
# array([0.47795598, 0.15505389])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.63300986970845

# %%
colours = ['red', 'blue', 'green', 'magenta', 'yellow']

plt.figure(figsize=(8,8))
for i in range(5):
    plt.scatter(X_reduced[y_kmeans == i,0], X_reduced[y_kmeans == i,1], s=100, c=colours[i], label='cluster' +str(i+1))
    plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:, 1], s=100, marker='*', c='orange', label='Centroids')

plt.title('Cluster of Disorders')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend()
plt.show()

# %%
y = kmeans.fit_predict(X_Scaled)
y
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# array([3, 2, 3, 0, 2, 4, 0, 2, 4, 2, 4, 4, 4, 2, 2, 3, 0, 2, 1, 4, 2, 0,
#        2, 0, 2, 2, 0, 4, 2, 2, 0, 0, 0, 0, 4, 0, 2, 0, 2, 2, 1, 2, 0, 0,
#        4, 0, 2, 0, 0, 2, 0, 2, 2, 4, 2, 0, 4, 0, 2, 2, 0, 1, 0, 2, 3, 2,
#        4, 0, 0, 1, 0, 0, 4, 4, 0, 0, 2, 4, 0, 4, 4, 2, 0, 1, 0, 0, 2, 2,
#        4, 4, 2, 0, 2, 2, 4, 0, 0, 3, 3, 4, 4, 4, 2, 2, 3, 1, 0, 0, 3, 1,
#        0, 2, 1, 3, 0, 0, 3, 1, 0, 0, 4, 2, 0, 0, 0, 0, 0, 4, 0, 0, 0, 2,
#        0, 0, 1, 1, 2, 3, 0, 0, 0, 0, 4, 4, 2, 0, 0, 3, 4, 0, 4, 0, 4, 0,
#        3, 0, 3, 2, 0, 2, 2, 0, 2, 4, 2, 3, 2, 1, 0, 2, 2, 0, 0, 3, 4, 0,
#        2, 0, 0, 4, 2, 2, 0, 0, 0, 0, 2, 0, 0, 0, 4, 0, 4, 0, 0, 3, 2, 0,
#        4, 4, 3, 0, 2, 0, 0, 0, 0, 0, 2, 4, 3, 3, 2, 0, 1, 3, 4, 4, 2, 3,
# ...

# %%
Normalize['Cluster'] = y
Normalize
# Out:
#                          Entity  Schizophrenia   Bipolar    Eating   Anxiety  \
# 0                   Afghanistan       0.070427  0.434745  0.023393  0.406788
# 1                       Albania       0.217529  0.432209  0.081972  0.193768
# 2                       Algeria       0.210590  0.555308  0.138585  0.430304
# 3                American Samoa       0.450833  0.171020  0.123381  0.182882
# 4          Andean Latin America       0.221393  0.629502  0.278566  0.319984
# ..                          ...            ...       ...       ...       ...
# 226  Western Sub-Saharan Africa       0.106574  0.357568  0.057802  0.123131
# 227                       World       0.469508  0.308834  0.133488  0.254712
# 228                       Yemen       0.108719  0.469438  0.064120  0.404617
# 229                      Zambia       0.061409  0.322676  0.057066  0.221429
# 230                    Zimbabwe       0.056304  0.328327  0.065620  0.153857
#
# ...

# %%
Normalize['Cluster'].value_counts()
# Out:
# Cluster
# 0    94
# 2    59
# 4    42
# 3    23
# 1    13
# Name: count, dtype: int64

# %%
Normalize[Normalize['Cluster'] == 0]['Entity'].to_list()
# Out:
# ['American Samoa',
#  'Angola',
#  'Bangladesh',
#  'Benin',
#  'Bhutan',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Cape Verde',
#  'Central African Republic',
#  'Central Sub-Saharan Africa',
#  'Chad',
#  'China',
#  'Comoros',
#  'Congo',
#  "Cote d'Ivoire",
#  'Democratic Republic of Congo',
#  'Djibouti',
#  'East Asia',
#  'Eastern Sub-Saharan Africa',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Ethiopia',
#  'Fiji',
#  'Gabon',
#  'Gambia',
#  'Ghana',
#  'Guam',
#  'Guinea',
#  'Guinea-Bissau',
#  'High-middle SDI',
#  'India',
#  'Indonesia',
#  'Kenya',
#  'Kiribati',
#  'Laos',
#  'Lesotho',
#  'Liberia',
#  'Low SDI',
#  'Low-middle SDI',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Marshall Islands',
#  'Mauritania',
#  'Mauritius',
#  'Micronesia (country)',
#  'Middle SDI',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Niger',
#  'Nigeria',
#  'North Korea',
# ...

# %%
Normalize[Normalize['Cluster'] == 1]['Entity'].to_list()
# Out:
# ['Belarus',
#  'Central Europe, Eastern Europe, and Central Asia',
#  'Eastern Europe',
#  'Estonia',
#  'Guatemala',
#  'Kazakhstan',
#  'Kyrgyzstan',
#  'Latvia',
#  'Lithuania',
#  'Moldova',
#  'Mongolia',
#  'Russia',
#  'Ukraine']

# %%
Normalize[Normalize['Cluster'] == 2]['Entity'].to_list()
# Out:
# ['Albania',
#  'Andean Latin America',
#  'Antigua and Barbuda',
#  'Armenia',
#  'Azerbaijan',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brunei',
#  'Bulgaria',
#  'Caribbean',
#  'Central Asia',
#  'Central Europe',
#  'Central Latin America',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Georgia',
#  'Grenada',
#  'Guyana',
#  'Haiti',
#  'High-income Asia Pacific',
#  'Honduras',
#  'Hungary',
#  'Jamaica',
#  'Japan',
#  'Latin America and Caribbean',
#  'Macedonia',
#  'Mexico',
#  'Montenegro',
#  'Nicaragua',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Poland',
#  'Puerto Rico',
#  'Romania',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'South Korea',
#  'Suriname',
#  'Tajikistan',
#  'Trinidad and Tobago',
#  'Turkmenistan',
# ...

# %%
Normalize[Normalize['Cluster'] == 3]['Entity'].to_list()
# Out:
# ['Afghanistan',
#  'Algeria',
#  'Bahrain',
#  'Egypt',
#  'Iran',
#  'Iraq',
#  'Jordan',
#  'Kuwait',
#  'Lebanon',
#  'Libya',
#  'Morocco',
#  'North Africa and Middle East',
#  'Oman',
#  'Palestine',
#  'Qatar',
#  'Saudi Arabia',
#  'Sudan',
#  'Syria',
#  'Tunisia',
#  'Turkey',
#  'United Arab Emirates',
#  'Uruguay',
#  'Yemen']

# %%
Normalize[Normalize['Cluster'] == 4]['Entity'].to_list()
# Out:
# ['Andorra',
#  'Argentina',
#  'Australasia',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Chile',
#  'Cyprus',
#  'Denmark',
#  'England',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Greenland',
#  'High SDI',
#  'High-income',
#  'Iceland',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'New Zealand',
#  'North America',
#  'Northern Ireland',
#  'Norway',
#  'Portugal',
#  'Scotland',
#  'Singapore',
#  'Southern Latin America',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Tropical Latin America',
#  'United Kingdom',
#  'United States',
#  'Wales',
#  'Western Europe']

# %%
Normalize[Normalize['Entity'] == 'United States']
# Out:
#             Entity  Schizophrenia   Bipolar    Eating   Anxiety  Drug use  \
# 217  United States       0.837899  0.380215  0.505412  0.679469  0.801956
#
#      Depression  Alcohol use  Cluster
# 217    0.583652     0.318176        4

# %%
kmeans = KMeans(n_clusters = 6, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X_Scaled)
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
X_reduced = pca.fit_transform(X_Scaled)

pca.explained_variance_ratio_
# Out:
# array([0.47795598, 0.15505389])

# %%
colours = ['red', 'blue', 'green', 'magenta', 'yellow', 'black']

plt.figure(figsize=(8,8))
for i in range(6):
    plt.scatter(X_reduced[y_kmeans == i,0], X_reduced[y_kmeans == i,1], s=100, c=colours[i], label='cluster' +str(i+1))
    plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:, 1], s=100, marker='*', c='orange', label='Centroids')

plt.title('Cluster of Disorders')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend()
plt.show()

# %%
y = kmeans.fit_predict(X_Scaled)
y
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# array([3, 1, 3, 2, 1, 0, 5, 1, 0, 1, 0, 0, 0, 1, 1, 3, 2, 1, 4, 0, 1, 5,
#        1, 2, 1, 1, 5, 0, 2, 1, 5, 5, 2, 5, 0, 5, 1, 5, 1, 1, 4, 1, 5, 5,
#        0, 2, 1, 5, 5, 1, 5, 1, 1, 0, 1, 5, 0, 5, 1, 1, 2, 4, 5, 1, 3, 1,
#        0, 5, 5, 4, 5, 2, 0, 0, 5, 5, 1, 0, 5, 0, 0, 1, 2, 1, 5, 5, 5, 1,
#        0, 0, 2, 2, 1, 1, 0, 2, 2, 3, 3, 0, 0, 0, 1, 2, 3, 1, 5, 2, 3, 1,
#        2, 1, 4, 3, 5, 5, 3, 4, 5, 2, 0, 1, 5, 5, 2, 2, 5, 0, 2, 5, 2, 1,
#        2, 2, 4, 5, 1, 3, 5, 2, 5, 2, 0, 0, 1, 5, 5, 3, 0, 2, 0, 2, 0, 2,
#        3, 2, 3, 1, 2, 1, 1, 2, 1, 0, 1, 3, 1, 4, 5, 1, 1, 2, 5, 3, 0, 5,
#        1, 2, 5, 2, 1, 1, 2, 5, 5, 2, 2, 5, 2, 2, 0, 5, 0, 2, 5, 3, 1, 5,
#        0, 0, 3, 2, 1, 5, 2, 2, 5, 2, 1, 0, 3, 3, 1, 5, 4, 3, 0, 0, 1, 3,
# ...

# %%
Normalize['Cluster'] = y
Normalize
# Out:
#                          Entity  Schizophrenia   Bipolar    Eating   Anxiety  \
# 0                   Afghanistan       0.070427  0.434745  0.023393  0.406788
# 1                       Albania       0.217529  0.432209  0.081972  0.193768
# 2                       Algeria       0.210590  0.555308  0.138585  0.430304
# 3                American Samoa       0.450833  0.171020  0.123381  0.182882
# 4          Andean Latin America       0.221393  0.629502  0.278566  0.319984
# ..                          ...            ...       ...       ...       ...
# 226  Western Sub-Saharan Africa       0.106574  0.357568  0.057802  0.123131
# 227                       World       0.469508  0.308834  0.133488  0.254712
# 228                       Yemen       0.108719  0.469438  0.064120  0.404617
# 229                      Zambia       0.061409  0.322676  0.057066  0.221429
# 230                    Zimbabwe       0.056304  0.328327  0.065620  0.153857
#
# ...

# %%
Normalize['Cluster'].value_counts()
# Out:
# Cluster
# 1    57
# 5    54
# 2    47
# 0    41
# 3    23
# 4     9
# Name: count, dtype: int64

# %%
Normalize[Normalize['Cluster'] == 0]['Entity'].to_list()
# Out:
# ['Andorra',
#  'Argentina',
#  'Australasia',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Chile',
#  'Cyprus',
#  'Denmark',
#  'England',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Greenland',
#  'High SDI',
#  'High-income',
#  'Iceland',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'New Zealand',
#  'North America',
#  'Northern Ireland',
#  'Norway',
#  'Portugal',
#  'Scotland',
#  'Southern Latin America',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Tropical Latin America',
#  'United Kingdom',
#  'United States',
#  'Wales',
#  'Western Europe']

# %%
Normalize[Normalize['Cluster'] == 1]['Entity'].to_list()
# Out:
# ['Albania',
#  'Andean Latin America',
#  'Antigua and Barbuda',
#  'Armenia',
#  'Azerbaijan',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Caribbean',
#  'Central Asia',
#  'Central Europe',
#  'Central Latin America',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Georgia',
#  'Grenada',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'Hungary',
#  'Jamaica',
#  'Kazakhstan',
#  'Kyrgyzstan',
#  'Latin America and Caribbean',
#  'Macedonia',
#  'Mexico',
#  'Montenegro',
#  'Nicaragua',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Poland',
#  'Puerto Rico',
#  'Romania',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Suriname',
#  'Tajikistan',
#  'Trinidad and Tobago',
#  'Turkmenistan',
#  'United States Virgin Islands',
#  'Uzbekistan',
# ...

# %%
Normalize[Normalize['Cluster'] == 2]['Entity'].to_list()
# Out:
# ['American Samoa',
#  'Bangladesh',
#  'Bhutan',
#  'Brunei',
#  'Cambodia',
#  'China',
#  'East Asia',
#  'Fiji',
#  'Guam',
#  'High-income Asia Pacific',
#  'High-middle SDI',
#  'India',
#  'Indonesia',
#  'Japan',
#  'Kiribati',
#  'Laos',
#  'Low-middle SDI',
#  'Malaysia',
#  'Maldives',
#  'Marshall Islands',
#  'Mauritius',
#  'Micronesia (country)',
#  'Middle SDI',
#  'Myanmar',
#  'Nepal',
#  'North Korea',
#  'Northern Mariana Islands',
#  'Oceania',
#  'Pakistan',
#  'Papua New Guinea',
#  'Philippines',
#  'Samoa',
#  'Seychelles',
#  'Singapore',
#  'Solomon Islands',
#  'South Asia',
#  'South Korea',
#  'Southeast Asia',
#  'Southeast Asia, East Asia, and Oceania',
#  'Sri Lanka',
#  'Taiwan',
#  'Thailand',
#  'Timor',
#  'Tonga',
#  'Vanuatu',
#  'Vietnam',
#  'World']

# %%
Normalize[Normalize['Cluster'] == 3]['Entity'].to_list()
# Out:
# ['Afghanistan',
#  'Algeria',
#  'Bahrain',
#  'Egypt',
#  'Iran',
#  'Iraq',
#  'Jordan',
#  'Kuwait',
#  'Lebanon',
#  'Libya',
#  'Morocco',
#  'North Africa and Middle East',
#  'Oman',
#  'Palestine',
#  'Qatar',
#  'Saudi Arabia',
#  'Sudan',
#  'Syria',
#  'Tunisia',
#  'Turkey',
#  'United Arab Emirates',
#  'Uruguay',
#  'Yemen']

# %%
Normalize[Normalize['Cluster'] == 4]['Entity'].to_list()
# Out:
# ['Belarus',
#  'Central Europe, Eastern Europe, and Central Asia',
#  'Eastern Europe',
#  'Estonia',
#  'Latvia',
#  'Lithuania',
#  'Moldova',
#  'Russia',
#  'Ukraine']

# %%
Normalize[Normalize['Cluster'] == 5]['Entity'].to_list()
# Out:
# ['Angola',
#  'Benin',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Cape Verde',
#  'Central African Republic',
#  'Central Sub-Saharan Africa',
#  'Chad',
#  'Comoros',
#  'Congo',
#  "Cote d'Ivoire",
#  'Democratic Republic of Congo',
#  'Djibouti',
#  'Eastern Sub-Saharan Africa',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Ethiopia',
#  'Gabon',
#  'Gambia',
#  'Ghana',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Kenya',
#  'Lesotho',
#  'Liberia',
#  'Low SDI',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mongolia',
#  'Mozambique',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Rwanda',
#  'Sao Tome and Principe',
#  'Senegal',
#  'Sierra Leone',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Southern Sub-Saharan Africa',
#  'Sub-Saharan Africa',
#  'Swaziland',
#  'Tanzania',
#  'Togo',
#  'Uganda',
#  'Western Sub-Saharan Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
Normalize[Normalize['Cluster'] == 5]['Entity'].to_list()
# Out:
# ['Angola',
#  'Benin',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Cape Verde',
#  'Central African Republic',
#  'Central Sub-Saharan Africa',
#  'Chad',
#  'Comoros',
#  'Congo',
#  "Cote d'Ivoire",
#  'Democratic Republic of Congo',
#  'Djibouti',
#  'Eastern Sub-Saharan Africa',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Ethiopia',
#  'Gabon',
#  'Gambia',
#  'Ghana',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Kenya',
#  'Lesotho',
#  'Liberia',
#  'Low SDI',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mongolia',
#  'Mozambique',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Rwanda',
#  'Sao Tome and Principe',
#  'Senegal',
#  'Sierra Leone',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Southern Sub-Saharan Africa',
#  'Sub-Saharan Africa',
#  'Swaziland',
#  'Tanzania',
#  'Togo',
#  'Uganda',
#  'Western Sub-Saharan Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
import scipy.cluster.hierarchy as sch

plt.figure(figsize=(15,6))
dendrogram = sch.dendrogram(sch.linkage(X_Scaled, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Disorders')
plt.ylabel('Euclidean Distances')
plt.show()

# %%
from sklearn.cluster import KMeans
lst = []
for i in range(1,11):
    model = KMeans(n_clusters = i, init = "k-means++", random_state = 42)
    model.fit(X)
    lst.append(model.inertia_)
# Out:
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /Users/thavaseelan/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# ...

# %%
print(lst)
# Out:
# [47.865843222656025, 30.938428165749553, 25.30523577887938, 21.2482884306388, 18.357245992180324, 15.45356938673313, 13.207511187164766, 11.262083515315476, 10.381842698810596, 9.625973615885323]

# %%
plt.plot(range(1,11), lst, color='r')
plt.xlabel('cluster')
plt.ylabel('varience')
plt.title('Line Graph to identify the No of Clusters')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1,11), sse, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('SSE')
plt.title('Elbow Method')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[212], line 2
#       1 plt.figure(figsize=(8,5))
# ----> 2 plt.plot(range(1,11), sse, marker='o')
#       3 plt.xlabel('Number of Clusters')
#       4 plt.ylabel('SSE')
#
# NameError: name 'sse' is not defined

# %%
from yellowbrick.cluster import KElbowVisualizer

elbow = KElbowVisualizer(kmeans, k=(2,10))
elbow.fit(X)
elbow.show()

# %%
model1 = KMeans(n_clusters=4, init="k-means", random_state=42)
y = model.fit_predict(X)
y

# %%
Normalize['Cluster'] = y
Normalize

# %%
Normalize['Cluster'].value_counts().sort_values().plot.barh()

# %%
Normalize['Cluster'].value_counts()[Normalize['Cluster'].unique()]

# %%
Normalize['Cluster'].value_counts().sort_values()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_reduced = pd.DataFrame(pca.fit_transform(X), columns=['PC1', 'PC2'])

X_reduced.head()

pca. explained_variance_ratio_

# %%
plt.scatter(X_reduced['PC1'], X_reduced['PC2'])
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title(f"Data Scatter after PCA")
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X_reduced)

# %%
plt.scatter(X_reduced['PC1'], X_reduced['PC2'], c=kmeans.labels_, cmap='rainbow')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('K-Means Clustering')
plt.show()
